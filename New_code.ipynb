# %%
# sample code
print('hello world')
# Out:
# hello world

# %%
1+1
# Out:
# 2

# %%
summary(mtcars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 summary(mtcars)
#
# NameError: name 'summary' is not defined
